# %%
import warnings
warnings.filterwarnings('ignore')
import FateAxis.tool.main_function as fa
import scanpy as sc
import numpy as np
import pandas as pd
from scipy.stats import wilcoxon
import FateAxis.tool.extractor as ext
import cospar as cs
import scipy.stats as stats
import cospar as cs
from scipy.stats import rankdata
import FateAxis.tool.preprocessor as pp
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.rcParams['figure.figsize'] = [6, 4.5]
plt.rcParams["savefig.dpi"] = 300

# %%
adata = sc.read_h5ad('/data/jiangjunyao/AEGAS_data/fate/Larry2020.h5ad')
adata.obs['time_info'] = 'late'
adata.obs.loc[adata.obs['celltype'] == 'undiff', 'time_info'] = 'early'

# %%
adata.obs['state_info'] = adata.obs['celltype']
adata = cs.pp.initialize_adata_object(adata)
# Out:
# Clones without any cells are removed.
# Time points with clonal info: ['early' 'late']
# WARNING: Default ascending order of time points are: ['early' 'late']. If not correct, run cs.hf.update_time_ordering for correction.
# WARNING: Please make sure that the count matrix adata.X is NOT log-transformed.

# %%
adata_2 = cs.tmap.infer_Tmap_from_state_info_alone(
    adata,
    initial_time_points=["early"],
    later_time_point="late",
    initialize_method="OT",
    OT_cost="GED",
    smooth_array=[20, 15, 10],
    max_iter_N=[1, 3],
    sparsity_threshold=0.2,
    use_full_Smatrix=True,compute_new=True
)
# Out:
# Step I: Generate pseudo clones where each cell has a unique barcode-----
# Step II: Perform joint optimization-----
# --------Infer transition map between initial time points and the later time one-------
# --------Current initial time point: early--------
# Step 0: Pre-processing and sub-sampling cells-------
# --> Compute similarity matrix: computing new; beta=0.1
# Smooth round: 1
# --> Time elapsed: 0.00918722152709961
# Smooth round: 2
# --> Time elapsed: 0.07190728187561035
# Smooth round: 3
# --> Time elapsed: 0.36817121505737305
# --> Orignal sparsity=0.24194253603536175, Thresholding
# --> Final sparsity=0.15743729445315183
# similarity matrix truncated (Smooth round=3):  0.37905192375183105
# Smooth round: 4
# --> Time elapsed: 0.7074954509735107
# --> Orignal sparsity=0.389852410759098, Thresholding
# --> Final sparsity=0.2441725267238419
# similarity matrix truncated (Smooth round=4):  0.39916229248046875
# Smooth round: 5
# --> Time elapsed: 0.9534826278686523
# --> Orignal sparsity=0.48158006503755424, Thresholding
# --> Final sparsity=0.3207093196096646
# similarity matrix truncated (Smooth round=5):  0.4107327461242676
# --> Save the matrix at every 5 rounds
# Smooth round: 6
# --> Time elapsed: 1.1588239669799805
# --> Orignal sparsity=0.5508917279913532, Thresholding
# --> Final sparsity=0.3870674160642429
# similarity matrix truncated (Smooth round=6):  0.41341710090637207
# Smooth round: 7
# --> Time elapsed: 1.314711332321167
# --> Orignal sparsity=0.6052698758574083, Thresholding
# --> Final sparsity=0.4446977168065229
# similarity matrix truncated (Smooth round=7):  0.4167766571044922
# Smooth round: 8
# --> Time elapsed: 1.4508705139160156
# --> Orignal sparsity=0.6494231686793931, Thresholding
# --> Final sparsity=0.49418944925551866
# similarity matrix truncated (Smooth round=8):  0.4141881465911865
# Smooth round: 9
# --> Time elapsed: 1.5607397556304932
# --> Orignal sparsity=0.6856942764420748, Thresholding
# --> Final sparsity=0.5366596380834558
# similarity matrix truncated (Smooth round=9):  0.4161841869354248
# Smooth round: 10
# --> Time elapsed: 1.6537621021270752
# --> Orignal sparsity=0.716393503068619, Thresholding
# --> Final sparsity=0.5732138886932173
# similarity matrix truncated (Smooth round=10):  0.41090965270996094
# --> Save the matrix at every 5 rounds
# Smooth round: 11
# --> Time elapsed: 1.734309434890747
# --> Orignal sparsity=0.7429681033666757, Thresholding
# --> Final sparsity=0.6049083459174599
# similarity matrix truncated (Smooth round=11):  0.40639543533325195
# Smooth round: 12
# --> Time elapsed: 1.7959880828857422
# --> Orignal sparsity=0.7662213128692689, Thresholding
# --> Final sparsity=0.6327478710629661
# similarity matrix truncated (Smooth round=12):  0.40399670600891113
# Smooth round: 13
# --> Time elapsed: 1.9005420207977295
# --> Orignal sparsity=0.7868819354863563, Thresholding
# --> Final sparsity=0.6574021079696044
# similarity matrix truncated (Smooth round=13):  0.39835667610168457
# Smooth round: 14
# --> Time elapsed: 1.9518113136291504
# --> Orignal sparsity=0.8054263817591067, Thresholding
# --> Final sparsity=0.6795223333392035
# similarity matrix truncated (Smooth round=14):  0.397003173828125
# Smooth round: 15
# --> Time elapsed: 1.951547384262085
# --> Orignal sparsity=0.8220330261779183, Thresholding
# --> Final sparsity=0.6996236869216071
# similarity matrix truncated (Smooth round=15):  0.41617918014526367
# --> Save the matrix at every 5 rounds
# Smooth round: 16
# --> Time elapsed: 1.994020700454712
# --> Orignal sparsity=0.8371666536422792, Thresholding
# --> Final sparsity=0.7179792337147461
# similarity matrix truncated (Smooth round=16):  0.4030003547668457
# Smooth round: 17
# --> Time elapsed: 2.029397964477539
# --> Orignal sparsity=0.8507426858891951, Thresholding
# --> Final sparsity=0.7348674387927163
# similarity matrix truncated (Smooth round=17):  0.3926091194152832
# Smooth round: 18
# --> Time elapsed: 2.061546564102173
# --> Orignal sparsity=0.8630796586216309, Thresholding
# --> Final sparsity=0.750564737901628
# similarity matrix truncated (Smooth round=18):  0.38672399520874023
# Smooth round: 19
# --> Time elapsed: 2.0912039279937744
# --> Orignal sparsity=0.8744700358372444, Thresholding
# --> Final sparsity=0.7652045507576891
# similarity matrix truncated (Smooth round=19):  0.38149523735046387
# Smooth round: 20
# --> Time elapsed: 2.118180274963379
# --> Orignal sparsity=0.8849309464400497, Thresholding
# --> Final sparsity=0.778934811931513
# similarity matrix truncated (Smooth round=20):  0.3823244571685791
# --> Save the matrix at every 5 rounds
# Step 1: Use OT method for initialization-------
# Finishing computing gene expression distance, used time 2.0504603385925293
# Compute new custom OT matrix
# Use uniform growth rate
# OT solver: duality_gap
# Finishing computing optial transport map, used time 2.1198854446411133
# Step 2: Jointly optimize the transition map and the initial clonal states-------
# --> original clone shape: (5392, 1998)
# --> After excluding zero-sized clones at t2: (5392, 1998)
# --> Sort clones by size (small to large)
# --> Infer the number of initial cells to extract for each clone in advance
# -----JointOpt Iteration 1: Infer initial clonal structure
# --> Inferring early clonal states: current clone id 0
# --> Inferring early clonal states: current clone id 100
# --> Inferring early clonal states: current clone id 200
# --> Inferring early clonal states: current clone id 300
# --> Inferring early clonal states: current clone id 400
# --> Inferring early clonal states: current clone id 500
# --> Inferring early clonal states: current clone id 600
# --> Inferring early clonal states: current clone id 700
# --> Inferring early clonal states: current clone id 800
# --> Inferring early clonal states: current clone id 900
# --> Inferring early clonal states: current clone id 1000
# --> Inferring early clonal states: current clone id 1100
# --> Inferring early clonal states: current clone id 1200
# --> Inferring early clonal states: current clone id 1300
# --> Inferring early clonal states: current clone id 1400
# --> Inferring early clonal states: current clone id 1500
# --> Inferring early clonal states: current clone id 1600
# --> Inferring early clonal states: current clone id 1700
# --> Inferring early clonal states: current clone id 1800
# --> Inferring early clonal states: current clone id 1900
# -----JointOpt Iteration 1: Update the transition map by CoSpar
# Load pre-computed similarity matrix
# --> Load from hard disk--------
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.1875777244567871
# --> Time elapsed:  0.13699579238891602
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.17193341255187988
# --> Time elapsed:  0.09009981155395508
# --> Compute similarity matrix: load existing data
# --> Time elapsed:  0.16142940521240234
# --> Time elapsed:  0.059229135513305664
# Iteration 1, Use smooth_round=20
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.05561542510986328
# --> Phase II: time elapsed --  0.14470696449279785
# Iteration 2, Use smooth_round=15
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.04629635810852051
# --> Phase II: time elapsed --  0.14333653450012207
# Iteration 3, Use smooth_round=10
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# --> Start to smooth the refined clonal map
# --> Phase I: time elapsed --  0.0390477180480957
# --> Phase II: time elapsed --  0.12481236457824707
# --> No need for Final Smooth (i.e., clonally-labeled states are the final state space for Tmap)
# --> ----Intraclone transition map----
# --> Clone normalization
# --> Relative time point pair index: 0
# --> Clone id: 0
# --> Clone id: 1000
# Finishing Joint Optimization, used time 11.85092306137085
# -----------Total used time: 88.56427597999573 s ------------

# %%
cs.tl.progenitor(adata_2,selected_fates=['Neutrophil','Monocyte'])
adata.obs['pred'] = np.nan
condition = adata_2.obs['progenitor_transition_map_Neutrophil'] == 1

adata_2.obs.loc[condition, 'pred'] = 'Neutrophil'
condition = adata_2.obs['progenitor_transition_map_Monocyte'] == 1

adata_2.obs.loc[condition, 'pred'] = 'Monocyte'
# Out:
# Results saved at adata.obs['fate_map_transition_map_Neutrophil']
# Results saved at adata.obs['fate_map_transition_map_Monocyte']
# Results saved at adata.obs['fate_bias_transition_map_Neutrophil*Monocyte']
# Results saved at adata.obs[f'progenitor_transition_map_Neutrophil'] and adata.obs[f'diff_trajectory_transition_map_Neutrophil']
# Results saved at adata.obs[f'progenitor_transition_map_Monocyte'] and adata.obs[f'diff_trajectory_transition_map_Monocyte']

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score
adata_final = adata_2[adata_2.obs.celltype=='undiff']
y_pred = adata_final.obs['pred']
y_true = adata_final.obs['lineage']

# 计算准确性

accuracy = accuracy_score(y_true, y_pred)

# 计算召回率

recall = recall_score(y_true, y_pred, average='macro')  # 根据需要选择合适的average参数

# 计算F1分数

f1 = f1_score(y_true, y_pred, average='macro')  # 根据需要选择合适的average参数

# 输出结果

print(f"Accuracy: {accuracy}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.7772539776075427
# Recall: 0.7781830106133679
# F1 Score: 0.7772490272576218
